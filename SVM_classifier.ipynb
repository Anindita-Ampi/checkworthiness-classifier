# %%
import os
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import roc_auc_score 
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# %%
data = pd.read_json("./data/3xNCS.json")

# %%
data.head()
# Out:
#    sentence_id  label                                               text
# 0         8967      1  In other words, I have seen his program costed...
# 1        27385      1  Our Navy is old -- excuse me, our Navy is smal...
# 2         9818      1  The unemployment, the number of people who are...
# 3        16794      1  Mr. Ford uh - actually has fewer people now in...
# 4        17588      1  Today it is up to about $38,000 of earnings th...

# %%
from sklearn.model_selection import train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(data.text, data.label, test_size = 0.20, random_state = 0)

# %%
tokenizer = Tokenizer(
    num_words = 1000,
    filters = '!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',
    lower=True,
    oov_token = '<UNK',
    char_level=False
)
tokenizer.fit_on_texts(x_train)

# %%
# Get our training data word index
word_index = tokenizer.word_index
print("Word index:\n", word_index)
# Out:
# Word index:
#  {'<UNK': 1, 'the': 2, 'to': 3, 'and': 4, 'of': 5, 'that': 6, 'i': 7, 'a': 8, 'in': 9, 'we': 10, 'have': 11, 'is': 12, 'it': 13, 'you': 14, 'for': 15, 'this': 16, 'on': 17, 'our': 18, 'be': 19, 'with': 20, 'are': 21, 'but': 22, 'not': 23, 'people': 24, 'think': 25, 'do': 26, 'as': 27, 'was': 28, 'he': 29, 'what': 30, 'going': 31, 'they': 32, 'about': 33, 'president': 34, 'if': 35, 'so': 36, 'all': 37, 'will': 38, 'would': 39, 'now': 40, "it's": 41, 'at': 42, 'can': 43, 'one': 44, 'because': 45, 'there': 46, 'has': 47, 'my': 48, 'who': 49, 'uh': 50, 'when': 51, "that's": 52, "don't": 53, 'out': 54, 'been': 55, 'get': 56, 'by': 57, 'or': 58, 'more': 59, 'want': 60, 'just': 61, "we're": 62, 'make': 63, 'an': 64, 'me': 65, 'know': 66, 'country': 67, 'had': 68, 'them': 69, 'up': 70, 'years': 71, 'very': 72, 'got': 73, "we've": 74, "i'm": 75, 'their': 76, 'said': 77, 'from': 78, 'those': 79, 'us': 80, 'well': 81, 'tax': 82, 'than': 83, 'these': 84, 'some': 85, 'say': 86, 'time': 87, 'which': 88, 'were': 89, 'america': 90, 'go': 91, 'government': 92, 'believe': 93, 'american': 94, 'world': 95, 'his': 96, 'should': 97, 'states': 98, 'mr': 99, 'need': 100, 'way': 101, 'year': 102, 'like': 103, 'billion': 104, 'first': 105, 'over': 106, 'other': 107, 'united': 108, 'percent': 109, 'your': 110, 'down': 111, 'right': 112, "i've": 113, 'back': 114, 'take': 115, 'work': 116, 'into': 117, 'no': 118, 'any': 119, 'also': 120, 'here': 121, 'jobs': 122, 'where': 123, 'then': 124, 'look': 125, 'things': 126, 'money': 127, 'care': 128, 'new': 129, 'million': 130, 'let': 131, 'senator': 132, 'did': 133, 'cut': 134, 'how': 135, 'good': 136, 'plan': 137, 'administration': 138, 'security': 139, 'health': 140, 'last': 141, 'every': 142, 'better': 143, 'only': 144, 'made': 145, 'see': 146, 'put': 147, 'done': 148, 'two': 149, 'sure': 150, 'give': 151, 'against': 152, 'could': 153, 'congress': 154, "you're": 155, 'important': 156, 'ought': 157, 'lot': 158, 'under': 159, "can't": 160, "they're": 161, 'governor': 162, 'war': 163, 'taxes': 164, 'question': 165, 'program': 166, '000': 167, 'again': 168, 'economy': 169, 'great': 170, 'thing': 171, 'four': 172, 'many': 173, 'before': 174, 'federal': 175, 'help': 176, 'kind': 177, 'much': 178, 'come': 179, 'state': 180, 'keep': 181, 'spending': 182, 'budget': 183, 'why': 184, "he's": 185, 'tell': 186, 'military': 187, 'education': 188, 'pay': 189, 'today': 190, 'same': 191, 'own': 192, 'after': 193, 'must': 194, 'fact': 195, 'even': 196, 'doing': 197, 'nuclear': 198, 'something': 199, 'social': 200, 'most': 201, 'americans': 202, 'strong': 203, "there's": 204, 'economic': 205, 'job': 206, 'around': 207, 'bill': 208, 'dollars': 209, 'national': 210, 'number': 211, 'programs': 212, 'increase': 213, 'able': 214, 'record': 215, 'talk': 216, 'ago': 217, 'next': 218, 'off': 219, 'point': 220, 'never': 221, 'business': 222, 'three': 223, 'working': 224, 'future': 225, "let's": 226, 'system': 227, "didn't": 228, 'long': 229, 'through': 230, 'nation': 231, 'being': 232, 'five': 233, 'medicare': 234, 'him': 235, 'policy': 236, 'children': 237, 'whether': 238, 'best': 239, 'problem': 240, 'defense': 241, 'deal': 242, 'part': 243, 'am': 244, 'insurance': 245, 'weapons': 246, 'says': 247, 'together': 248, 'understand': 249, 'still': 250, 'schools': 251, 'energy': 252, 'support': 253, 'bring': 254, 'went': 255, 'really': 256, 'issue': 257, 'since': 258, 'between': 259, 'eight': 260, 'making': 261, 'voted': 262, 'she': 263, 'too': 264, 'history': 265, '5': 266, 'hope': 267, 'campaign': 268, 'ever': 269, 'life': 270, '1': 271, 'leadership': 272, 'house': 273, 'use': 274, 'another': 275, "i'll": 276, 'middle': 277, 'bush': 278, 'cost': 279, 'foreign': 280, 'iraq': 281, 'soviet': 282, 'free': 283, 'continue': 284, '4': 285, "you've": 286, 'everybody': 287, 'far': 288, "we'll": 289, 'talking': 290, 'change': 291, 'position': 292, 'women': 293, 'home': 294, 'tonight': 295, '2': 296, 'came': 297, 'may': 298, 'little': 299, 'differe ...

# %%
# Encode training data sentences into sequences
train_sequences = tokenizer.texts_to_sequences(x_train)

# Get max training sequence length
maxlen = max([len(x) for x in train_sequences])

# Pad the training sequences
pad_type = trunc_type = 'pre'
train_padded = pad_sequences(train_sequences, padding=pad_type, truncating=trunc_type, maxlen=maxlen, value=0.0)

# Output the results of our work

print("\nTraining sequences:\n", train_sequences)
# Out:
# Training sequences:
# Out:
# maxlen:  151
#
# Padded training sequences:
#  [[  0   0   0 ...  11 500  15]
#  [  0   0   0 ... 115 106   1]
#  [  0   0   0 ... 367  15  69]
#  ...
#  [  0   0   0 ...   6  10 100]
#  [  0   0   0 ...   2 218   1]
#  [  0   0   0 ...  17 197   6]]
#
# Padded training shape: (8844, 151)
# Training sequences data type: <class 'list'>
# Padded Training sequences data type: <class 'numpy.ndarray'>

# %%
test_sequences = tokenizer.texts_to_sequences(x_valid)
test_padded = pad_sequences(test_sequences, padding=pad_type, truncating=trunc_type, maxlen=maxlen, value=0.0)

print("Testing sequences:\n", test_sequences)
print("\nPadded testing sequences:\n", test_padded)
print("\nPadded testing shape:",test_padded.shape)

#x_valid = pad_sequences(x_valid, maxlen=max_review_length, padding=pad_type, truncating=trunc_type, value=0)
# Out:
# Testing sequences:
#  [[62, 1, 377, 109, 5, 2, 1, 1], [10, 11, 874, 130, 24, 390, 119, 245, 42, 37, 4, 7, 146, 69, 37, 2, 87], [9, 2, 523, 1, 10, 68, 1, 13, 111, 3, 33, 1], [4, 75, 31, 3, 181, 17, 1, 69, 45, 7, 53, 25, 62, 1, 264, 299], [13, 1, 1, 2, 348, 432, 6, 1, 11, 1, 130, 1, 6, 161, 23, 777, 6, 656, 14, 274, 69, 58, 14, 726, 69], [10, 53, 151, 391, 18, 613, 174, 10, 729, 111, 42, 2, 1, 829], [13, 1, 320, 9, 195, 2, 320, 7, 61, 773, 190, 2, 320, 12, 1, 42, 1, 130, 15, 16, 548, 102, 1, 130], [22, 30, 263, 321, 86, 12, 6, 34, 384, 47, 1, 665, 4, 665, 5, 24, 61, 2, 101, 13, 12], [370, 41, 8, 443, 240, 27, 99, 278, 247, 22, 1, 23, 64, 1, 240], [49, 47, 55, 2, 354, 49, 47, 570, 3, 181, 182, 159, 301], [40, 13, 12, 593, 6, 48, 701, 4, 1, 1, 1, 15, 331, 153, 491, 3, 189, 8, 299, 59, 9, 164, 9, 476], [81, 7, 77, 8, 462, 1, 217, 1, 6, 14, 153, 1, 2, 525, 5, 327, 4, 1, 4, 685, 127, 42, 2, 191, 87], [4, 74, 145, 13, 447, 6, 224, 20, 18, 669, 4, 503, 6, 10, 21, 1, 3, 1, 119, 1, 1, 88, 392, 1, 1, 20, 6, 1, 604, 5, 2, 95], [10, 11, 965, 2, 211, 5, 304, 6, 21, 1, 4, 31, 3, 19, 1], [64, 257, 7, 11, 55, 444, 9, 15, 173, 173, 71, 4, 75, 501, 5, 2, 116, 5, 2, 116, 6, 113, 148, 46, 475, 20, 132, 520], [680, 2, 34, 1, 124, 5, 311, 50, 2, 67, 321, 1, 4, 1, 1, 77, 2, 1, 50, 2, 862, 5, 2, 108, 98, 12, 1, 37, 8, 351, 5, 964, 272], [36, 30, 12, 2, 342], [35, 75, 696, 4, 155, 952, 4, 7, 43, 56, 14, 3, 555, 65, 52, 136], [22
22, 30, 10, 615, 438, 355, 12, 8, 1, 884, 15, 2, 277, 437], [4, 75, 1, 10, 43, 398, 85, 1, 17, 13, 174, 10, 56, 230, 121], [46, 12, 8, 171, 303, 772, 677], [36, 6, 39, 19, 1, 211, 44], [370, 10, 11, 3, 19, 1, 4, 1, 4, 7, 244], [35, 14, 1, 463, 18, 674, 1, 5, 246, 3, 2, 277, 629, 144, 421, 109, 645, 3, 797], [51, 10, 255, 9, 3, 1, 4, 10, 89, 214, 3, 1, 428, 2, 1, 46, 45, 5, 2, 1, 1, 4, 2, 1, 6, 10, 68, 1, 3, 1], [22, 7, 120, 93, 6, 92, 47, 2, 1, 2, 175, 92, 47, 2, 1, 3, 176, 1, 70, 344, 4, 446, 1, 5, 344, 4, 3, 446, 1, 123, 2, 94, 24, 43, 1], [4, 75, 1, 62, 31, 9, 2, 112, 1], [7, 66, 37, 33, 7 ...
#
# Padded testing sequences:
#  [[  0   0   0 ...   2   1   1]
#  [  0   0   0 ...  37   2  87]
#  [  0   0   0 ...   3  33   1]
#  ...
#  [  0   0   0 ...  13 145 859]
#  [  0   0   0 ...   4   1   1]
#  [  0   0   0 ...   1   5 265]]
#
# Padded testing shape: (2212, 151)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state = 0)
classifier.fit(train_padded, y_train)
# Out:
# SVC(random_state=0)

# %%
testdata = pd.read_csv("./data/groundtruth.csv")

# %%
testdata.head()
# Out:
#    Sentence_id                                               Text  \
# 0           26      You know, I saw a movie - "Crocodile Dundee."
# 1           80  We're consuming 50 percent of the world's coca...
# 2          129   That answer was about as clear as Boston harbor.
# 3          131                          Let me help the governor.
# 4          172  We've run up more debt in the last eight years...
#
#            Speaker   Speaker_title Speaker_party         File_id  Length  \
# 0      George Bush  Vice President    REPUBLICAN  1988-09-25.txt       9
# 1  Michael Dukakis        Governor      DEMOCRAT  1988-09-25.txt       8
# 2      George Bush  Vice President    REPUBLICAN  1988-09-25.txt       9
# 3      George Bush  Vice President    REPUBLICAN  1988-09-25.txt       5
# 4  Michael Dukakis        Governor      DEMOCRAT  1988-09-25.txt      22
#
#    Line_number  Sentiment  Verdict
# 0           26   0.000000        0
# 1           80  -0.740979        1
# 2          129   0.000000       -1
# 3          131   0.212987       -1
# 4          172  -0.268506        1

# %%
x_test = testdata['Text']
test_xsequences = tokenizer.texts_to_sequences(x_test)
test_xpadded = pad_sequences(test_xsequences, padding=pad_type, truncating=trunc_type, maxlen=maxlen, value=0.0)

# %%
# combining UFS sentences and CFS sentences into FC sentences
testdata.loc[testdata['Verdict'] == 1, 'label'] = 1
testdata.loc[testdata['Verdict'] == 0, 'label'] = 1
testdata.loc[testdata['Verdict'] == -1, 'label'] = 0

y = testdata['label'].astype(np.int64)

# %%
y_hat = classifier.predict(test_xpadded)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(test_xpadded)
cm = confusion_matrix(y, y_pred)
print(cm)
accuracy_score(y, y_pred)
# Out:
# [[722   9]
#  [234  67]]
# 0.7645348837209303
